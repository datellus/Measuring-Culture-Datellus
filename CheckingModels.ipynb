# %%
import pandas as pd
import numpy as np
import gensim

# %%
model = gensim.models.Word2Vec.load("models/w2v/w2v.mod")

# %%
model.wv.most_similar("innovation")
# Out:
# [('new_product', 0.6604917049407959),
#  ('newness', 0.6463975310325623),
#  ('new_product_development', 0.6024763584136963),
#  ('core_brand', 0.5873862504959106),
#  ('innovative', 0.582003653049469),
#  ('marketing_campaign', 0.5752111673355103),
#  ('product_news', 0.5521693229675293),
#  ('product_innovation', 0.5508625507354736),
#  ('sandwich_cracker', 0.5417418479919434),
#  ('talent', 0.5377938747406006)]

# %%
model.wv.vectors
# Out:
# array([[-0.05436012,  0.77885264,  0.10908374, ...,  0.7142795 ,
#          0.8248991 ,  0.20775372],
#        [-0.12918822, -0.10257245, -0.30722752, ..., -0.29414335,
#          0.5049646 ,  0.04516116],
#        [ 0.34306186, -0.15772815,  0.08563114, ..., -0.18002811,
#          0.19404267,  0.13189349],
#        ...,
#        [ 0.02009475,  0.05330577,  0.09104277, ...,  0.07067086,
#          0.08407865,  0.00642201],
#        [ 0.13971953,  0.01514208,  0.1360771 , ...,  0.0745208 ,
#         -0.05193724,  0.00907723],
#        [ 0.14163607, -0.09687914,  0.06288836, ...,  0.01033299,
#          0.28647333, -0.00121491]], dtype=float32)

# %%
words = list(w for w in model.wv.index_to_key)

# %%
model.wv['innovation']
# Out:
# array([ 6.54696703e-01,  1.17556723e-02,  2.41076171e-01, -4.08167899e-01,
#         7.25935459e-01,  2.41974607e-01, -1.16602683e+00, -8.40105355e-01,
#         2.39801839e-01,  9.08472613e-02,  6.76112950e-01, -2.17144683e-01,
#        -9.84607160e-01, -4.17879522e-01, -1.79609883e+00, -7.35596001e-01,
#         8.66816103e-01, -5.26065230e-01, -1.15414582e-01,  4.73115332e-02,
#         3.96567017e-01,  4.04150337e-01,  1.34357953e+00, -2.27012366e-01,
#        -5.01700401e-01,  2.15155646e-01,  4.81327653e-01, -9.64550972e-01,
#         1.51398456e+00, -1.47481728e+00,  1.32986993e-01, -9.27063406e-01,
#        -5.65674245e-01, -1.62512159e+00,  9.35217619e-01,  1.42499936e+00,
#        -2.44616777e-01,  2.56414503e-01, -6.05058789e-01,  3.88045460e-01,
#        -2.55584657e-01,  2.46875882e+00,  5.78274369e-01,  1.94875538e+00,
#         2.60467857e-01,  9.80244875e-01,  2.87606746e-01, -9.32703614e-01,
# ...

# %%
len(words)
# Out:
# 16956
