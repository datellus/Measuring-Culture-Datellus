# %%
import pandas as pd
import numpy as np

# %%
dictionary = pd.read_csv("outputs/dict/expanded_dict.csv")

# %%
dictionary
# Out:
#           integrity               teamwork  innovation       respect  \
# 0    responsibility          collaboration  innovation      employee
# 1             trust          collaborative  innovative      talented
# 2       responsible            cooperation   efficient        talent
# 3       transparent            collaborate    creative  job_security
# 4     work_together            cooperative  efficiency   salesperson
# ..              ...                    ...         ...           ...
# 455             NaN     routing_scheduling         NaN           NaN
# 456             NaN  production_capability         NaN           NaN
# 457             NaN               localize         NaN           NaN
# 458             NaN         routing_mobile         NaN           NaN
# 459             NaN  distribution_platform         NaN           NaN
#
#               quality
# 0            customer
# 1             quality
# 2               guest
# 3    customer_service
# ...

# %%
dictionary[["integrity"]].dropna().head(50)
# Out:
#                     integrity
# 0              responsibility
# 1                       trust
# 2                 responsible
# 3                 transparent
# 4               work_together
# 5                transparency
# 6              accountability
# 7                    stand_up
# 8                 intelligent
# 9                   energized
# 10                  visionary
# 11              balancing_act
# 12                  boil_down
# 13                 logistical
# 14               common_sense
# 15                credibility
# 16                   meantime
# 17                stakeholder
# 18               key_supplier
# 19       execution_standpoint
# 20                    deserve
# 21               learn_lesson
# 22                  win_-_win
# 23                    culture
# 24                   seamless
# 25              communication
# 26                  undermine
# 27                  emotional
# 28                  conscious
# 29                     advice
# ...
