# %% [markdown]
# # __Debugging Scores__

# %%
import itertools
import os
import pickle
from operator import itemgetter
from pathlib import Path
from collections import Counter, OrderedDict, defaultdict
import pandas as pd
from tqdm import tqdm as tqdm
import math
import numpy as np
import global_options
from culture import culture_dictionary, file_util

# %%
current_dict_path = "outputs/dict/expanded_dict.csv"
culture_dict, all_dict_words = culture_dictionary.read_dict_from_csv(current_dict_path)
# Out:
# Importing dict: outputs/dict/expanded_dict.csv
# Number of words in integrity dimension: 366
# Number of words in teamwork dimension: 460
# Number of words in innovation dimension: 287
# Number of words in respect dimension: 232
# Number of words in quality dimension: 202

# %%
len(all_dict_words)
# Out:
# 1547

# %%
word_sim_weights = culture_dictionary.compute_word_sim_weights(current_dict_path)

# %% [markdown]
# ## __Pre Score : Construct Doc Level Corpus__

# %%
def construct_doc_level_corpus(sent_corpus_file, sent_id_file):
    """Construct document level corpus from sentence level corpus and write to disk.
    Dump "corpus_doc_level.pickle" and "doc_ids.pickle" to Path(global_options.OUTPUT_FOLDER, "scores", "temp"). 
    
    Arguments:
        sent_corpus_file {str or Path} -- The sentence corpus after parsing and cleaning, each line is a sentence
        sent_id_file {str or Path} -- The sentence ID file, each line correspond to a line in the sent_co(docID_sentenceID)
    
    Returns:
        [str], [str], int -- a tuple of a list of documents, a list of document IDs, and the number of documents
    """
    print("Constructing doc level corpus")
    # sentence level corpus
    sent_corpus = file_util.file_to_list(sent_corpus_file)
    sent_IDs = file_util.file_to_list(sent_id_file)
    assert len(sent_IDs) == len(sent_corpus)
    # doc id for each sentence
    doc_ids = [x.split("_")[0] for x in sent_IDs]
    # concat all text from the same doc
    id_doc_dict = defaultdict(lambda: "")
    for i, id in enumerate(doc_ids):
        id_doc_dict[id] += " " + sent_corpus[i]
    # create doc level corpus
    corpus = list(id_doc_dict.values())
    doc_ids = list(id_doc_dict.keys())
    assert len(corpus) == len(doc_ids)
    with open(
        Path(global_options.OUTPUT_FOLDER, "scores", "temp", "corpus_doc_level.pickle"),
        "wb",
    ) as out_f:
        pickle.dump(corpus, out_f)
    with open(
        Path(global_options.OUTPUT_FOLDER, "scores", "temp", "doc_ids.pickle"), "wb"
    ) as out_f:
        pickle.dump(doc_ids, out_f)
    N_doc = len(corpus)
    return corpus, doc_ids, N_doc

# %% [markdown]
# __Toma el texto procesado Trigram lo carga y lo une__

# %%
sent_corpus = file_util.file_to_list(sent_corpus_file)

# %%
sent_corpus[:10]
# Out:
# ['thank_sir',
#  'lady_gentleman time will begin_question_answer_session',
#  'operator_instruction',
#  '[ner:ordinal]_question_come [ner:person] [ner:organization]',
#  'please_go_ahead',
#  'good_morning_guy',
#  'fabulous_quarter',
#  'thanks [ner:person]',
#  'difference increase revenue increase margin [ner:ordinal]_party increase cost',
#  'tell [ner:date] cost_increase']

# %%
sent_corpus_file = "data/processed/trigram/documents.txt"
sent_id_file = "data/processed/parsed/document_sent_ids.txt"

# %%
corpus, doc_ids, N_doc = construct_doc_level_corpus(sent_corpus_file,sent_id_file)
# Out:
# Constructing doc level corpus

# %%
N_doc
# Out:
# 1393

# %%
corpus[0][:200]
# Out:
# ' thank_sir lady_gentleman time will begin_question_answer_session operator_instruction [ner:ordinal]_question_come [ner:person] [ner:organization] please_go_ahead good_morning_guy fabulous_quarter tha'

# %% [markdown]
# ## __Calculate DF : Crea un Diccionario con la ocurrencia de cada palabra en words_in_doc__

# %%
def calculate_df(corpus):
    """Calcualte and dump a document-freq dict for all the words.
    
    Arguments:
        corpus {[str]} -- a list of documents
    
    Returns:
        {dict[str: int]} -- document freq for each word
    """
    print("Calculating document frequencies.")
    # document frequency
    df_dict = defaultdict(int)
    for doc in tqdm(corpus):
        doc_splited = doc.split()
        words_in_doc = set(doc_splited)
        for word in words_in_doc:
            df_dict[word] += 1
    # save df dict
    with open(
        Path(global_options.OUTPUT_FOLDER, "scores", "temp", "doc_freq.pickle"), "wb"
    ) as f:
        pickle.dump(df_dict, f)
    return df_dict

# %%
word_doc_freq = calculate_df(corpus)
# Out:
# Calculating document frequencies.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1393/1393 [00:00<00:00, 2084.46it/s]

# %%
word_doc_freq.get("back")
# Out:
# 1241

# %%
len(word_doc_freq.keys())
# Out:
# 82162

# %% [markdown]
# # __Computing using TF-IDF__

# %%
doc = corpus[0]

# %%
contribution = defaultdict(int)
results = []

# %%
document = doc.split()
dimension_count = OrderedDict()

# %%
expanded_words = culture_dict

# %%
for dimension in expanded_words:
    dimension_count[dimension] = 0
c = Counter(document)

# %%
dimension_count
# Out:
# OrderedDict([('integrity', 0),
#              ('teamwork', 0),
#              ('innovation', 0),
#              ('respect', 0),
#              ('quality', 0)])

# %%
c
# Out:
# Counter({'thank_sir': 1,
#          'lady_gentleman': 1,
#          'time': 12,
#          'will': 34,
#          'begin_question_answer_session': 1,
#          'operator_instruction': 2,
#          '[ner:ordinal]_question_come': 1,
#          '[ner:person]': 41,
#          '[ner:organization]': 8,
#          'please_go_ahead': 10,
#          'good_morning_guy': 3,
#          'fabulous_quarter': 1,
#          'thanks': 9,
#          'difference': 2,
#          'increase': 19,
#          'revenue': 3,
#          'margin': 14,
#          '[ner:ordinal]_party': 1,
#          'cost': 6,
#          'tell': 2,
#          '[ner:date]': 141,
#          'cost_increase': 1,
#          'want': 6,
#          'handle': 2,
#          'sure': 2,
#          'think': 60,
#          'table': 1,
#          'sorry': 1,
#          '[ner:location]': 44,
#          'come': 6,
#          'listen': 1,
#          'go': 40,
#          'try': 5,
#          'give': 13,
#          'religion': 1,
#          '[ner:money]': 44,
#          '[ner:duration]': 40,
#          'revenue_per_[ner:duration]': 3,
#          'cost_per_[ner:duration]': 3,
#          'combination_factor': 1,
#          'know': 29,
#          '[ner:set]': 4,
#          'rig_report': 1,
#          'experience': 1,
#          'fair_amount': 1,
#          'rain': 1,
#          'mean': 4,
#          'crew': 2,
#          'sit': 1,
#          'wait': 2,
#          'move': 18,
#          'recall': 1,
#          '[ner:number]': 66,
#          'rig': 62,
#          'several': 2,
#          'would': 52,
#          'factor': 4,
#          'another': 3,
#          'labor_cost': 1,
#          'go_up': 8,
#          'term': 9,
#          'way': 7,
#          'schedule': 1,
#          'person': 12,
#          'enough': 4,
#          'work': 11,
#          'primary': 1,
#          'thing': 11,
#          'mobilization_cost': 2,
#          'help_offset': 1,
#          'go_forward': 1,
#          'weather': 4,
#          'talk': 5,
#          'price_increase': 1,
#          'impact': 10,
#          'fall': 2,
#          'income_statement': 1,
#          'could': 17,
#          'beginning': 1,
#          'question': 11,
#          'yes': 10,
#          'use': 4,
#          'charge': 5,
#          'mob': 1,
#          'depend': 4,
#          'far': 8,
#          'double': 1,
#          'price': 6,
#          'pretty_much': 3,
#          'raise': 1,
#          'like': 11,
#          'say': 19,
#          'good': 5,
#          'quarter_guy': 1,
#          'curious': 2,
#          'business': 12,
#          'guess': 20,
#          'trucking_side': 1,
#          'trucking': 3,
#          'well': 8,
#          'need': 4,
#          'truck': 4,
#          'shortage': 1,
#          'area': 10,
#          'help': 3,
#          'problem': 6,
#          'add': 2,
#          'additional': 7,
#          'take': 9,
#          'lot': 12,
#          'money': 2,
#          'reason': 2,
#          'new': 3,
#          'tandem': 1,
#          'get': 29,
#          'field': 2,
#          'pay': 3,
#          'stuff': 1,
#          'wrong': 1,
#          'location': 1,
#          'part': 2,
#          'average_revenue_per': 3,
#          'contract': 5,
#          'report': 2,
#          'effect': 12,
#          'disconnect': 2,
#          'relate': 3,
#          'item': 1,
#          'reimbursable': 1,
#          'customer': 7,
#          'primarily': 1,
#          'least': 4,
#          'probably': 3,
#          'keep_pace': 1,
#          'competitor': 2,
#          'announce': 1,
#          'conference_call': 1,
#          'payroll_tax': 1,
#          'property_tax': 1,
#          'expect': 7,
#          'still': 3,
#          'significantly': 1,
#          'may': 7,
#          'guy': 9,
#          'see': 41,
#          'estimate': 2,
#          'fica': 1,
#          'occur': 4,
#          'aware': 1,
#          'kind': 22,
#          'hand': 2,
#          'quarter_quarter': 2,
#          '[ner:ordinal]': 7,
#          'similar': 2,
#          'likely': 1,
#          'field_payroll': 1,
#          'pass_along': 1,
#          'high': 15,
#          'comment': 5,
#          'drop_bottom': 1,
#          'okay': 10,
#          'gentleman': 2,
#          'appreciate': 5,
#          'let': 3,
#          'ask': 3,
#          'thank': 9,
#          'next_question_come': 6,
#          'good_morning': 5,
#          'hi': 1,
#          'selection': 1,
#          'finally': 4,
#          'arrive': 1,
#          'hear_correctly': 1,
#          'bulk': 1,
#          'drop_bottom_line': 1,
#          'look': 27,
#          'market': 11,
#          'around': 5,
#          'use_cash': 1,
#          'raise_dividend': 1,
#          'institute': 2,
#          'dividend': 1,
#          'versus': 3,
#          'share_repurchase': 1,
#          'decision': 1,
#          'actively': 1,
#          'consider': 8,
#          'regular': 1,
#          '[ner:set]_basis': 2,
#          'board': 3,
#          'buyback': 2,
#          'place': 4,
#          'opportunistic': 1,
#          'structured': 1,
#          'reduction': 1,
#          'capital': 2,
#          'certainly': 14,
#          'discussion': 1,
#          'something': 2,
#          'progress': 3,
#          'move_forward': 1,
#          'drop': 3,
#          '[ner:misc]': 9,
#          'rig_activity': 2,
#          'image': 1,
#          'pressure': 1,
#          'sequentially': 2,
#          'strong': 2,
#          'offset': 2,
#          'completely': 1,
#          'seasonal': 1,
#          'come_down': 1,
#          'necessarily': 3,
#          'rate': 6,
#          'contribute': 2,
#          'overall': 5,
#          'become': 5,
#          'non-player': 1,
#          'run': 9,
#          'otherwise': 1,
#          'mute': 1,
#          'pull_back': 1,
#          'course': 5,
#          'back': 13,
#          'less': 2,
#          'understood': 1,
#          'activate': 3,
#          'long': 7,
#          'demand_warrant': 1,
#          'understand_correctly': 1,
#          'market_share': 1,
#          'vis': 1,
#          '_-_vis': 1,
#          'neighbor': 5,
#          'activate_rig': 2,
#          'pace': 1,
#          'player': 2,
#          'really': 11,
#          'significant': 6,
#          'capacity': 3,
#          'ability': 1,
#          'understand': 4,
#          'anybody_else': 1,
#          'context': 1,
#          'capex': 3,
#          'clearly': 2,
#          'dependent': 1,
#          'demand': 14,
#          'point': 14,
#          'thought': 3,
#          'bring_out': 4,
#          'total': 2,
#          'include': 6,
#          'pressure_pumping': 2,
#          'etc.': 3,
#          'run_rate': 4,
#          'lastly': 2,
#          'stock_option_expense': 1,
#          'could_give_update': 1,
#          'happen': 6,
#          '[ner:ordinal]_half': 1,
#          'accountant': 1,
#          'seem': 3,
#          'focus': 1,
#          'matter': 2,
#          '[ner:money]_per_share': 2,
#          'obviously': 5,
#          'back_half': 1,
#          'calculation': 1,
#          'drive': 2,
#          'option': 1,
#          'vest': 1,
#          'even': 3,
#          'large': 3,
#          'scale_effect': 1,
#          'stock_option': 1,
#          'restricted_stock': 3,
#          'g&a_number': 2,
#          'time_period': 1,
#          'partly': 1,
#          'expense': 1,
#          'therefore': 1,
#          'little': 4,
#          'overhang': 1,
#          'employee_stock_option': 1,
#          're-activization_cost': 1,
#          'bring_it_out': 1,
#          'cost_per': 2,
#          'drill_strength': 2,
#          'continue': 10,
#          'fairly_steady': 1,
#          'state': 1,
#          'pretty_steady': 1,
#          'much': 6,
#          'drill_pipe': 2,
#          'food_chain': 2,
#          'call': 2,
#          'order': 2,
#          'joint': 1,
#          'activation': 1,
#          'replacement': 1,
#          'real': 3,
#          'strength': 1,
#          'wear_out': 1,
#          'number': 6,
#          'excellent': 1,
#          'wonder_could': 2,
#          'give_insight': 1,
#          'south_[ner:location]': 1,
#          'activity': 4,
#          'everywhere': 3,
#          'tremendous': 2,
#          'equipment': 3,
#          'pick': 1,
#          'never': 3,
#          'change': 6,
#          'major': 2,
#          'oil_company': 2,
#          'large_independent': 1,
#          'buy': 2,
#          'production': 1,
#          'development_opportunity': 1,
#          'exist': 2,
#          'commodity_price': 7,
#          'comfortable': 1,
#          'believe': 4,
#          'stay': 3,
#          'sensitivity': 1,
#          'economics': 5,
#          'make': 8,
#          'prospects': 1,
#          'viable': 1,
#          'drill': 8,
#          'budget': 1,
#          'every': 2,
#          'old': 1,
#          'plan': 4,
#          'reactivate': 2,
#          'particular': 1,
#          'across_board': 1,
#          'salesman': 1,
#          'fight': 1,
#          'internally': 2,
#          'particularly': 2,
#          'split_up': 1,
#          'couple': 4,
#          'list': 1,
#          'project': 3,
#          'great': 6,
#          '[ner:ordinal]_question': 1,
#          'seasonal_decline': 1,
#          'job': 4,
#          'generate': 1,
#          '[ner:percent]': 9,
#          'bad': 1,
#          'wonder': 1,
#          'side': 1,
#          'sort': 4,
#          'decline': 1,
#          'couple_thing': 1,
#          'attribute': 1,
#          'warm': 1,
#          'muddy': 1,
#          'road': 1,
#          'truly': 1,
#          'difficult': 3,
#          'gas': 3,
#          'nobody': 2,
#          'stop': 1,
#          'anything': 1,
#          'hunt': 2,
#          'season': 2,
#          'holiday': 2,
#          'accustomed': 1,
#          'normal': 3,
#          'shutdown': 1,
#          'last_question': 2,
#          'indication': 1,
#          'early': 2,
#          'reactivation': 1,
#          'readdress': 1,
#          'thanks_guy': 2,
#          'henrion': 1,
#          'nice_quarter': 1,
#          'couple_question': 1,
#          'rig_reactivation_program': 1,
#          'usual': 1,
#          'running': 1,
#          'put_out': 1,
#          'stack': 1,
#          'rig_category': 1,
#          'beyond': 3,
#          'rest': 3,
#          'measure': 1,
#          'approach': 1,
#          'next': 3,
#          'high_quality': 1,
#          'horsepower_rig': 1,
#          'many': 2,
#          'specifics': 1,
#          'competitive_reason': 1,
#          'first': 1,
#          'class_rig': 1,
#          'perfectly': 2,
#          'situate': 1,
#          'suitable': 1,
#          'activity_level': 1,
#          'fact': 4,
#          'without': 1,
#          'hesitancy': 1,
#          'whatsoever': 1,
#          'maybe': 6,
#          'accelerate': 1,
#          'offer': 2,
#          'assurance': 1,
#          'feel_like': 2,
#          'close': 3,
#          'account': 1,
#          'repair': 2,
#          'hard': 4,
#          'effect_measure': 1,
#          'plus': 1,
#          'put': 4,
#          'level': 3,
#          'bring': 2,
#          'go_out': 1,
#          'observe': 1,
#          'world': 3,
#          'tight': 1,
#          'rig_market_customer': 1,
#          'find': 1,
#          'accept': 2,
#          'might': 4,
#          'horsepower': 2,
#          'interesting': 2,
#          'target': 2,
#          'absorb': 1,
#          'highly_confident': 1,
#          'right': 5,
#          'drilling_completion_fluid': 1,
#          'offshore': 1,
#          'globe_lease': 1,
#          'strengthen': 3,
#          'deep': 1,
#          'water_activity': 1,
#          'outlook': 1,
#          'assume': 2,
#          'everything': 2,
#          'clear': 2,
#          'though': 1,
#          'gulf': 1,
#          'last': 4,
#          'housekeep_question': 1,
#          'sg': 1,
#          'kick_up': 1,
#          'key': 7,
#          'whatever': 1,
#          'increment': 1,
#          'g&a': 1,
#          'mention_early': 1,
#          'bump': 1,
#          'somewhere_around_[ner:money]': 3,
#          'tax_rate_assumption': 1,
#          'actually': 4,
#          'purpose': 1,
#          'model': 1,
#          'indiscernible': 2,
#          'next_question': 4,
#          'clarify': 2,
#          'actual': 1,
#          'individual': 2,
#          'unit': 2,
#          'active': 5,
#          'example': 3,
#          'rig_count': 5,
#          'volatile': 1,
#          'due': 1,
#          'mention': 4,
#          'range': 3,
#          'ever': 1,
#          'average': 4,
#          'given': 1,
#          'recent': 1,
#          'exactly': 3,
#          'come_back': 3,
#          'set': 1,
#          'miss': 1,
#          'want_make_sure': 1,
#          'misinterpret': 1,
#          'moderate': 1,
#          'intend': 1,
#          'decent': 1,
#          'visibility': 6,
#          'leave': 1,
#          'analyst': 1,
#          'draw_conclusion': 1,
#          'utilization': 1,
#          'drop_off': 1,
#          'benefit': 1,
#          'case': 3,
#          'ultimately': 1,
#          'suggest': 2,
#          'quarter': 1,
#          'want_ask': 1,
#          'take_off': 1,
#          'projection': 1,
#          'pressed': 1,
#          'slow_down': 2,
#          'anticipate': 1,
#          'lend': 1,
#          'fleet': 4,
#          'show': 2,
#          'time_contract': 1,
#          'control': 1,
#          'competition': 2,
#          'affect': 1,
#          'pricing': 2,
#          'point_out': 1,
#          'nobody_else': 1,
#          'spare_capacity': 2,
#          'party': 1,
#          'company': 1,
#          'walk': 1,
#          'amount': 1,
#          'date': 1,
#          'reflect': 1,
#          'acquisition': 1,
#          'partial': 1,
#          'contribution': 1,
#          'somewhere_around': 1,
#          'patterson_-_uti_growth': 1,
#          'frankly': 2,
#          'contract_rate': 1,
#          'method': 1,
#          'relevant': 1,
#          'divergence': 1,
#          'cash_margin': 3,
#          'influence': 1,
#          'negotiate': 1,
#          'move_they_up': 1,
#          'finish': 1,
#          'little_less': 1,
#          'normally': 1,
#          'certain_area': 1,
#          'switch': 1,
#          'equal': 1,
#          'ahead': 2,
#          'quickly': 1,
#          'start': 8,
#          'basically': 2,
#          'muted': 1,
#          'somewhat': 1,
#          'take_over': 1,
#          'complete': 1,
#          'muting': 1,
#          'remain': 1,
#          'count': 2,
#          'pool': 2,
#          'reactivatable': 1,
#          'identify': 1,
#          'none': 3,
#          'mark': 1,
#          'indicate': 1,
#          'base': 1,
#          'make_sense': 1,
#          'part_rig': 1,
#          'along': 1,
#          'put_they_out': 1,
#          'come_out': 3,
#          'stack_rig': 2,
#          'good_morning_everybody': 1,
#          'exceed': 2,
#          'supply': 2,
#          'little_bit': 2,
#          'supply_side_response': 1,
#          'discuss': 3,
#          'availability': 1,
#          'perspective': 2,
#          'timing': 1,
#          'address': 1,
#          'happy': 1,
#          'talk_little_bit': 1,
#          'build': 2,
#          'itis': 1,
#          'radar_screen': 1,
#          'yet': 4,
#          'anywhere_close': 1,
#          'one': 1,
#          'competitive': 5,
#          'foreseeable': 1,
#          'marketplace': 2,
#          'scatter': 1,
#          'insignificant': 1,
#          'comparison': 1,
#          'gut_feel': 1,
#          'commodity': 2,
#          'opportunity': 3,
#          'sense': 1,
#          'mix_change': 1,
#          'risk_profile': 1,
#          'i.e.': 1,
#          'shift': 1,
#          'away': 3,
#          'development': 2,
#          'exploration': 1,
#          'mix': 2,
#          'development_drilling': 1,
#          'exploration_drilling': 1,
#          'oil_field': 1,
#          'oil': 3,
#          'small': 1,
#          'spacing': 1,
#          '[ner:money]_barrel': 2,
#          'go_on': 1,
#          'unbelievable': 1,
#          'economic': 1,
#          'efficiency': 5,
#          'throughout': 1,
#          'period': 2,
#          'slow': 4,
#          'response': 1,
#          'efficiency_gain': 1,
#          'mod': 1,
#          'improvement': 1,
#          'rig_efficiency': 1,
#          'crystal_ball': 1,
#          'efficient': 2,
#          'category': 1,
#          'drilling_contractor': 1,
#          'respond': 1,
#          'continuous': 1,
#          'turn': 4,
#          'allow': 2,
#          'last_upturn': 1,
#          'big': 3,
#          'technology': 1,
#          'thousand': 1,
#          'fast': 2,
#          'barrel': 1,
#          'create': 1,
#          'answer': 2,
#          '[ner:person]_ph_[ner:organization]': 1,
#          'quick': 1,
#          'modeling_question': 1,
#          'd&a': 1,
#          'depreciation': 1,
#          'capex_estimate': 1,
#          'take_it_up': 1,
#          'somewhere': 2,
#          'quick_question': 1,
#          'hit': 3,
#          'head': 1,
#          'tend': 1,
#          'look_out': 1,
#          'base_upon': 1,
#          'peak_margin': 1,
#          'dramatically': 1,
#          'eclipse': 1,
#          'view': 1,
#          'whether': 2,
#          'pretty': 2,
#          'side_thing': 1,
#          'extremely_strong': 1,
#          'half': 1,
#          'peak_level': 1,
#          'expansion': 1,
#          'keep': 2,
#          'always': 6,
#          'incremental': 3,
#          'issue': 3,
#          'superior': 1,
#          'return_shareholder': 1,
#          'slight': 1,
#          'discount': 1,
#          'seasonality': 1,
#          'operation': 1,
#          'true': 1,
#          'break': 1,
#          'evaluation': 1,
#          'subject': 2,
#          'creep': 1,
#          'push': 1,
#          'person_issue': 1,
#          'tough': 1,
#          'hit_wall': 1,
#          'staffing_level': 1,
#          'barrier': 2,
#          'train': 1,
#          'different': 2,
#          'methodology_way': 1,
#          'surprise': 1,
#          'train_person': 1,
#          'young': 1,
#          'industry': 3,
#          'decimate': 1,
#          'correct': 1,
#          'methodical': 1,
#          'trend': 3,
#          'put_rig_out': 1,
#          'hurdle': 1,
#          'staffing': 1,
#          'follow_suit': 1,
#          'big_hurdle': 1,
#          'doubling': 1,
#          'easy': 1,
#          'accomplish': 1,
#          'already': 1,
#          'pleased': 1,
#          'grow': 1,
#          'maintain': 1,
#          'service_business': 1,
#          'labor': 1,
#          'single': 1,
#          'follow_-_up_question': 2,
#          'mr._[ner:person]': 1,
#          'step': 1,
#          'phone': 1,
#          'please': 1,
#          'characterize': 1,
#          'conversation': 2,
#          'potential': 1,
#          'time_horizon': 1,
#          'fair_statement': 1,
#          'term_contract': 4,
#          'downturn': 1,
#          'lead': 1,
#          'commodity_price_downturn': 1,
#          'anybody': 1,
#          'apparent': 1,
#          'cross': 1,
#          'supply_-_demand_curve': 1,
#          'crude_oil': 3,
#          'crude': 1,
#          'oil_perspective': 1,
#          'also': 1,
#          'natural': 1,
#          'gas_perspective': 1,
#          'crack': 1,
#          'crude_oil_price': 1,
#          'natural_gas': 2,
#          'decoupling': 1,
#          'natural_gas_price': 1,
#          'value': 1,
#          'ratio': 3,
#          'return': 2,
#          'short': 1,
#          'reach': 1,
#          'able': 1,
#          'produce': 1,
#          'incentive': 1,
#          'lock_in': 1,
#          'condition': 1,
#          'term_commitment': 1,
#          'speak': 1,
#          'recouple': 1,
#          'specific': 1,
#          'clarification': 1,
#          'term_contract_question': 1,
#          'achieve': 1,
#          'proper': 1,
#          'upside': 1,
#          'operate': 1,
#          'vacuum': 1,
#          'make_judgment': 1,
#          'appropriate': 1,
#          'put_aside': 1,
#          'enforceability': 1,
#          'simplistic': 1,
#          'per_rig_[ner:duration]': 2,
#          'complicated': 1,
#          'particulars': 1,
#          'bear': 2,
#          'responsibility': 2,
#          'delay': 2,
#          'play': 2,
#          'whole_series': 1,
#          'binomial': 2,
#          'education': 1,
#          'staff': 1,
#          'workforce': 1,
#          'upturn': 1,
#          'unemployment': 2,
#          'remember': 1,
#          'low': 3,
#          'draw': 2,
#          'low_end': 1,
#          'employee': 1,
#          'wages': 3,
#          'compete': 2,
#          'market_place': 2,
#          'kid': 1,
#          'school': 1,
#          'drilling_rig': 2,
#          'college': 1,
#          'make_money': 1,
#          'anywhere_else': 1,
#          'unskilled': 1,
#          'laborer': 1,
#          'would_like_turn': 1,
#          'conference_back': 1,
#          'conclude': 1,
#          'thank_everyone_join': 1,
#          'appreciate_support': 1,
#          'take_care': 1,
#          'lady_gentleman_conclude': 1,
#          'patterson_-_uti_[ner:date]': 1,
#          'like_listen_replay': 1,
#          'conference_please_dial': 1,
#          '[ner:number]_enter_access_code': 1,
#          'follow_pound_sign': 1,
#          'thank_participate': 1,
#          'conference': 1})

# %%
df_dict = word_doc_freq

# %%
len(document)
# Out:
# 2637

# %%
for pair in c.items(): # Itero en cada tupla del Counter que cuenta repeticiones de palabras en formato (palabra , repeticiones)
    for dimension, words in expanded_words.items(): #Itero en Categoría y sus palabras
        if pair[0] in words: # Reviso si la palabra del Documento está en el diccionario de palabras de la categoría
            w_ij = pair[1] * math.log(N_doc / df_dict[pair[0]]) 
            ### pair[1] = cantidad de veces que la palabra aparece en el documento
            ### N_doc = Total de documentos
            ### df_dict[pair[0]] = Total de veces que la palabra en el total de documentos
            dimension_count[dimension] += w_ij ## Aumentamos la cuenta de la dimensión en el valor obtenido
            contribution[pair[0]] += w_ij / len(document) ## Creamos la contribución dividiendo por el total de palabras del documento

dimension_count = OrderedDict(sorted(dimension_count.items(), key=lambda t: t[0]))

# %%
dimension_count
# Out:
# OrderedDict([('innovation', 30.205946679520117),
#              ('integrity', 12.241819641474017),
#              ('quality', 42.91781604784668),
#              ('respect', 20.447753453549858),
#              ('teamwork', 27.798470991302864)])

# %%
result = list(dimension_count.values())
result.append(len(document))
results.append(result)
results = np.array(results)

# %%
results
# Out:
# array([[  30.20594668,   12.24181964,   42.91781605,   20.44775345,
#           27.79847099, 2637.        ]])

# %%
df = pd.DataFrame(
        results, columns=sorted(list(expanded_words.keys())) + ["document_length"]
    )
df["Doc_ID"] = "Document_ID"

# %%
df
# Out:
#    innovation  integrity    quality    respect   teamwork  document_length  \
# 0   30.205947   12.24182  42.917816  20.447753  27.798471           2637.0
#
#         Doc_ID
# 0  Document_ID
